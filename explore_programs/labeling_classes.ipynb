# %%
import pandas as pd
import numpy as np
import re
import csv

# %%
hashmap = {}

with open(r"explore_programs_geneds_raw.txt") as file:
   # if count % 3 == 1:
    content = file.readlines()

    tag_set = set()

    for i in range(len(content)):
        if i % 3 == 2:

            if len(content[i].strip()) > 2:
           
                val = content[i].strip()

                #print(val)

                first = val[:2]
                second = val[2:]

                lst = [first, second]
             #   print("hi i got here")
             ##   print(first, second)
                for z in lst:
                  #  print(z, type(z))
                    if z not in hashmap:
                        hashmap[z.strip()] = [content[i-2][:], re.split(r'#', content[i-1])[1:]]
                    else:
                        hashmap[z.strip()].append([content[i-2][:], re.split(r'#', content[i-1])[1:]])

           #     print("I worked", hashmap)

            elif content[i].strip() not in hashmap:

                hashmap[content[i].strip()] = [[content[i-2][:], set(re.split(r'#', content[i-1])[1:])]]
                print(hashmap)
            else:

                hashmap[content[i].strip()].append([content[i-2][:], set(re.split(r'#', content[i-1])[1:])])
 
        if i % 3 == 1:
            tag_set.update(re.split(r'#', content[i])[1:])
           # print(re.split(r'#', content[i])[1:])

 #   print(tag_set)
print(hashmap)
# Out:
# {'AH': [['AAAD-A 132 Recent African American and African Diaspora Literature\n', ['Africa', 'Central America', 'Culture', 'History', 'Human Rights', 'Literature', 'North America', 'South America', 'Writing\n']]]}
# {'AH': [['AAAD-A 132 Recent African American and African Diaspora Literature\n', ['Africa', 'Central America', 'Culture', 'History', 'Human Rights', 'Literature', 'North America', 'South America', 'Writing\n']], ['AAAD-A 150 Survey of the Culture of Black Americans\n', ['Art', 'Crafts', 'Culture', 'History', 'Literature', 'North America', 'Performance', 'Religion\n']], ['AAAD-A 169 Introduction to African American Literature\n', ['Literature', 'North America\n']], ['AAAD-A 238 Communication in Black America\n', ['Communication', 'Culture', 'History', 'Language', 'Media', 'North America\n']], ['AAAD-A 249 African American Autobiography\n', ['Culture', 'History', 'Human Rights', 'Literature', 'North America', 'Religion', 'Writing\n']], ['AAAD-A 277 Images of Blacks in Films: 1903-1950s\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 278 Contemporary Black Film\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 290 Sociocultural Perspective of African American Music\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAAD-A 295 Survey of Hip Hop\n', ['Culture', 'History', 'Media', 'Music', 'North America', 'Pop Culture\n']], ['AAAD-A 297 Popular Music of Black America\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAST-A 200 Asian American Literature\n', ['Culture', 'History', 'Literature', 'North America\n']], ['AAST-A 201 Asian Diaspora Experience\n', ['Art', 'Asia', 'Culture', 'History', 'Literature', 'Media', 'Movies', 'Music', 'News', 'North America', 'Performance', 'Photography\n']]], 'SH': ['AAAD-A 154 History of Race in the Americas\n', ['Central America', 'Culture', 'Government', 'History', 'Human Rights', 'North America', 'South America\n'], ['AAAD-A 156 Black Liberation Struggles against Jim Crow and Apartheid\n', ['Africa', 'Conflict Resolution', 'Government', 'History', 'Human Rights', 'Legal Issues', 'North America', 'Philosophy\n']], ['AAAD-A 203 Studying Blacks of the New World: African Americans and Africans in the African Diaspora\n', ['Culture', 'History', 'North America\n']], ['AAAD-A 210 Black Women in the Diaspora\n', ['Gender and LGBTQ+', 'History', 'Human Rights', 'North America\n']], ['AAAD-A 250 U.S. Contemporary Minorities\n', ['Culture', 'History', 'Human Rights', 'North America\n']], ['AAAD-A 255 The Black Church in America\n', ['Culture', 'Human Rights', 'North America', 'Religion\n']], ['AAAD-A 257 Monuments, Memories: Jewish and Black Experiences\n', ['Culture', 'History', 'Human Rights\n']], ['AAAD-A 264 History of Sports and the African American Experience\n', ['Culture', 'History', 'Human Rights', 'North America', 'Pop Culture', 'Sports\n']], ['AAAD-A 265 Modern Sports and the African American Experience\n', ['Culture', 'History', 'Human Rights', 'North America', 'Pop Culture', 'Sports\n']], ['AAST-A 101 Introduction to Asian American Studies\n', ['Culture', 'History', 'Human Rights', 'Literature', 'Movies', 'North America\n']]], 'WC': ['AAAD-A 154 History of Race in the Americas\n', ['Central America', 'Culture', 'Government', 'History', 'Human Rights', 'North America', 'South America\n'], ['AAAD-A 156 Black Liberation Struggles against Jim Crow and Apartheid\n', ['Africa', 'Conflict Resolution', 'Government', 'History', 'Human Rights', 'Legal Issues', 'North America', 'Philosophy\n']], ['AAAD-A 221 Dance in the African Diaspora\n', ['Culture', 'History', 'North America', 'Performance', 'Pop Culture\n']], ['AAST-A 201 Asian Diaspora Experience\n', ['Art', 'Asia', 'Culture', 'History', 'Literature', 'Media', 'Movies', 'Music', 'News', 'North America', 'Performance', 'Photography\n']]], 'NS': [['ABEH-A 101 Introduction to Animal Behavior\n', ['Animals', 'Science\n']]]}
# {'AH': [['AAAD-A 132 Recent African American and African Diaspora Literature\n', ['Africa', 'Central America', 'Culture', 'History', 'Human Rights', 'Literature', 'North America', 'South America', 'Writing\n']], ['AAAD-A 150 Survey of the Culture of Black Americans\n', ['Art', 'Crafts', 'Culture', 'History', 'Literature', 'North America', 'Performance', 'Religion\n']], ['AAAD-A 169 Introduction to African American Literature\n', ['Literature', 'North America\n']], ['AAAD-A 238 Communication in Black America\n', ['Communication', 'Culture', 'History', 'Language', 'Media', 'North America\n']], ['AAAD-A 249 African American Autobiography\n', ['Culture', 'History', 'Human Rights', 'Literature', 'North America', 'Religion', 'Writing\n']], ['AAAD-A 277 Images of Blacks in Films: 1903-1950s\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 278 Contemporary Black Film\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 290 Sociocultural Perspective of African American Music\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAAD-A 295 Survey of Hip Hop\n', ['Culture', 'History', 'Media', 'Music', 'North America', 'Pop Culture\n']], ['AAAD-A 297 Popular Music of Black America\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAST-A 200 Asian American Literature\n', ['Culture', 'History', 'Literature', 'North America\n']], ['AAST-A 201 Asian Diaspora Experience\n', ['Art', 'Asia', 'Culture', 'History', 'Literature', 'Media', 'Movies', 'Music', 'News', 'North America', 'Performance', 'Photography\n']]], 'SH': ['AAAD-A 154 History of Race in the Americas\n', ['Central America', 'Culture', 'Government', 'History', 'Human Rights', 'North America', 'South America\n'], ['AAAD-A 156 Black Liberation Struggles against Jim Crow and Apartheid\n', ['Africa', 'Conflict Resolution', 'Government', 'History', 'Human Rights', 'Legal Issues', 'North America', 'Philosophy\n']], ['AAAD-A 203 Studying Blacks of the New World: African Americans and Africans in the African Diaspora\n', ['Culture', 'History', 'North America\n']], ['AAAD-A 210 Black Women in the Diaspora\n', ['Gender and LGBTQ+', 'History', 'Human Rights', 'North America\n']], ['AAAD-A 250 U.S. Contemporary Minorities\n', ['Culture', 'History', 'Human Rights', 'North America\n']], ['AAAD-A 255 The Black Church in America\n', ['Culture', 'Human Rights', 'North America', 'Religion\n']], ['AAAD-A 257 Monuments, Memories: Jewish and Black Experiences\n', ['Culture', 'History', 'Human Rights\n']], ['AAAD-A 264 History of Sports and the African American Experience\n', ['Culture', 'History', 'Human Rights', 'North America', 'Pop Culture', 'Sports\n']], ['AAAD-A 265 Modern Sports and the African American Experience\n', ['Culture', 'History', 'Human Rights', 'North America', 'Pop Culture', 'Sports\n']], ['AAST-A 101 Introduction to Asian American Studies\n', ['Culture', 'History', 'Human Rights', 'Literature', 'Movies', 'North America\n']]], 'WC': ['AAAD-A 154 History of Race in the Americas\n', ['Central America', 'Culture', 'Government', 'History', 'Human Rights', 'North America', 'South America\n'], ['AAAD-A 156 Black Liberation Struggles against Jim Crow and Apartheid\n', ['Africa', 'Conflict Resolution', 'Government', 'History', 'Human Rights', 'Legal Issues', 'North America', 'Philosophy\n']], ['AAAD-A 221 Dance in the African Diaspora\n', ['Culture', 'History', 'North America', 'Performance', 'Pop Culture\n']], ['AAST-A 201 Asian Diaspora Experience\n', ['Art', 'Asia', 'Culture', 'History', 'Literature', 'Media', 'Movies', 'Music', 'News', 'North America', 'Performance', 'Photography\n']], ['AFRI-A 100 Introduction to African Studies\n', ['Africa', 'Art', 'Culture', 'Environment', 'Gender and LGBTQ+', 'Government', 'Healthcare', 'Helping People', 'History', 'Human Behavior', 'Human Rights', 'International', 'Literature', 'Media', 'Movies', 'Pop Culture', 'Religion', 'Sustainability', 'Writing\n']]], 'NS': [['ABEH-A 101 Introduction to Animal Behav ...
# {'AH': [['AAAD-A 132 Recent African American and African Diaspora Literature\n', ['Africa', 'Central America', 'Culture', 'History', 'Human Rights', 'Literature', 'North America', 'South America', 'Writing\n']], ['AAAD-A 150 Survey of the Culture of Black Americans\n', ['Art', 'Crafts', 'Culture', 'History', 'Literature', 'North America', 'Performance', 'Religion\n']], ['AAAD-A 169 Introduction to African American Literature\n', ['Literature', 'North America\n']], ['AAAD-A 238 Communication in Black America\n', ['Communication', 'Culture', 'History', 'Language', 'Media', 'North America\n']], ['AAAD-A 249 African American Autobiography\n', ['Culture', 'History', 'Human Rights', 'Literature', 'North America', 'Religion', 'Writing\n']], ['AAAD-A 277 Images of Blacks in Films: 1903-1950s\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 278 Contemporary Black Film\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 290 Sociocultural Perspective of African American Music\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAAD-A 295 Survey of Hip Hop\n', ['Culture', 'History', 'Media', 'Music', 'North America', 'Pop Culture\n']], ['AAAD-A 297 Popular Music of Black America\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAST-A 200 Asian American Literature\n', ['Culture', 'History', 'Literature', 'North America\n']], ['AAST-A 201 Asian Diaspora Experience\n', ['Art', 'Asia', 'Culture', 'History', 'Literature', 'Media', 'Movies', 'Music', 'News', 'North America', 'Performance', 'Photography\n']], ['AMST-A 200 Comparative American Identities\n', ['Culture', 'Gender and LGBTQ+', 'Government', 'History', 'Human Rights', 'North America\n']], ['AMST-A 202 U.S. Arts and Media\n', ['Art', 'Media', 'North America\n']], ['ANTH-A 208 Topics in the Anthropology of the Arts and Expressive Behavior\n', ['Art', 'Crafts', 'Culture', 'History', 'Literature', 'Music', 'Performance', 'Religion\n']], ['ANTH-A 288 Sex, Drugs, and Rock-n-Roll (Subversive Culture)\n', ['Culture', 'Gender and LGBTQ+', 'Music', 'Pop Culture\n']], ['ANTH-E 203 Stigma and the Expressive Arts: Cultivating Compassion\n', ['Art', 'Culture', 'Gender and LGBTQ+', 'Helping People', 'Human Rights', 'Movies', 'Music', 'Performance', 'Photography', 'Writing\n']], ['ANTH-E 208 Global Jazz, Reggae, and Hip-Hop: African Diasporic Music Beyond the African Diaspora\n', ['Africa', 'Central America', 'Culture', 'Gender and LGBTQ+', 'History', 'Music', 'North America', 'Religion', 'South America\n']], ['ANTH-E 220 Performing Human/Nature: Defining Relationships with the Environment\n', ['Art', 'Culture', 'Journalism', 'Literature', 'Movies', 'Music\n']], ['ANTH-E 270 Captivity Narratives\n', ['Culture', 'History', 'Human Rights', 'International', 'Language', 'Literature\n']], ['ARTH-A 155 Introduction to African Art\n', ['Africa', 'Art', 'History\n']], ['ARTH-A 160 Introduction to East Asian Art\n', ['Art', 'Asia', 'Culture', 'History\n']], ['ARTH-A 200 Topics in Art History (Topic: Art of the Great Depression)\n', ['Art', 'History', 'Movies', 'Photography\n']], ['ARTH-A 203 Machine Age Modern: European Art, 1848-1939\n', ['Art', 'Culture', 'Europe', 'History', 'Media', 'Movies', 'Photography', 'Pop Culture\n']], ['ARTH-A 204 Buddha and Beyond: Keywords for the Study of East Asian Buddhist Art\n', ['Art', 'Asia', 'Language', 'Religion\n']], ['ARTH-A 205 Baroque Art in Europe: From Caravaggio to Rembrandt\n', ['Art', 'Europe', 'History\n']], ['ARTH-A 206 Classical Art and Archaeology\n', ['Art', 'Culture', 'Europe', 'History\n']], ['ARTH-A 207 Introduction to Contemporary Art and Its Discontents, 1960 to the Present\n', ['Art', 'Culture', 'History', 'Pop Culture\n']], ['ARTH-A 220 American Arts/American Identities\n', ['Art', 'Culture', 'History', 'North America', 'Photography', 'Pop Culture\n']], ['ARTH-A 224 The Gothic Cathedral\n', ['Art', 'Design', 'Europe', 'Government', 'History', 'Music', 'Religion\n']], ['ARTH-A 226 Envisioning the Sac ...
# {'AH': [['AAAD-A 132 Recent African American and African Diaspora Literature\n', ['Africa', 'Central America', 'Culture', 'History', 'Human Rights', 'Literature', 'North America', 'South America', 'Writing\n']], ['AAAD-A 150 Survey of the Culture of Black Americans\n', ['Art', 'Crafts', 'Culture', 'History', 'Literature', 'North America', 'Performance', 'Religion\n']], ['AAAD-A 169 Introduction to African American Literature\n', ['Literature', 'North America\n']], ['AAAD-A 238 Communication in Black America\n', ['Communication', 'Culture', 'History', 'Language', 'Media', 'North America\n']], ['AAAD-A 249 African American Autobiography\n', ['Culture', 'History', 'Human Rights', 'Literature', 'North America', 'Religion', 'Writing\n']], ['AAAD-A 277 Images of Blacks in Films: 1903-1950s\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 278 Contemporary Black Film\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 290 Sociocultural Perspective of African American Music\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAAD-A 295 Survey of Hip Hop\n', ['Culture', 'History', 'Media', 'Music', 'North America', 'Pop Culture\n']], ['AAAD-A 297 Popular Music of Black America\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAST-A 200 Asian American Literature\n', ['Culture', 'History', 'Literature', 'North America\n']], ['AAST-A 201 Asian Diaspora Experience\n', ['Art', 'Asia', 'Culture', 'History', 'Literature', 'Media', 'Movies', 'Music', 'News', 'North America', 'Performance', 'Photography\n']], ['AMST-A 200 Comparative American Identities\n', ['Culture', 'Gender and LGBTQ+', 'Government', 'History', 'Human Rights', 'North America\n']], ['AMST-A 202 U.S. Arts and Media\n', ['Art', 'Media', 'North America\n']], ['ANTH-A 208 Topics in the Anthropology of the Arts and Expressive Behavior\n', ['Art', 'Crafts', 'Culture', 'History', 'Literature', 'Music', 'Performance', 'Religion\n']], ['ANTH-A 288 Sex, Drugs, and Rock-n-Roll (Subversive Culture)\n', ['Culture', 'Gender and LGBTQ+', 'Music', 'Pop Culture\n']], ['ANTH-E 203 Stigma and the Expressive Arts: Cultivating Compassion\n', ['Art', 'Culture', 'Gender and LGBTQ+', 'Helping People', 'Human Rights', 'Movies', 'Music', 'Performance', 'Photography', 'Writing\n']], ['ANTH-E 208 Global Jazz, Reggae, and Hip-Hop: African Diasporic Music Beyond the African Diaspora\n', ['Africa', 'Central America', 'Culture', 'Gender and LGBTQ+', 'History', 'Music', 'North America', 'Religion', 'South America\n']], ['ANTH-E 220 Performing Human/Nature: Defining Relationships with the Environment\n', ['Art', 'Culture', 'Journalism', 'Literature', 'Movies', 'Music\n']], ['ANTH-E 270 Captivity Narratives\n', ['Culture', 'History', 'Human Rights', 'International', 'Language', 'Literature\n']], ['ARTH-A 155 Introduction to African Art\n', ['Africa', 'Art', 'History\n']], ['ARTH-A 160 Introduction to East Asian Art\n', ['Art', 'Asia', 'Culture', 'History\n']], ['ARTH-A 200 Topics in Art History (Topic: Art of the Great Depression)\n', ['Art', 'History', 'Movies', 'Photography\n']], ['ARTH-A 203 Machine Age Modern: European Art, 1848-1939\n', ['Art', 'Culture', 'Europe', 'History', 'Media', 'Movies', 'Photography', 'Pop Culture\n']], ['ARTH-A 204 Buddha and Beyond: Keywords for the Study of East Asian Buddhist Art\n', ['Art', 'Asia', 'Language', 'Religion\n']], ['ARTH-A 205 Baroque Art in Europe: From Caravaggio to Rembrandt\n', ['Art', 'Europe', 'History\n']], ['ARTH-A 206 Classical Art and Archaeology\n', ['Art', 'Culture', 'Europe', 'History\n']], ['ARTH-A 207 Introduction to Contemporary Art and Its Discontents, 1960 to the Present\n', ['Art', 'Culture', 'History', 'Pop Culture\n']], ['ARTH-A 220 American Arts/American Identities\n', ['Art', 'Culture', 'History', 'North America', 'Photography', 'Pop Culture\n']], ['ARTH-A 224 The Gothic Cathedral\n', ['Art', 'Design', 'Europe', 'Government', 'History', 'Music', 'Religion\n']], ['ARTH-A 226 Envisioning the Sac ...
# {'AH': [['AAAD-A 132 Recent African American and African Diaspora Literature\n', ['Africa', 'Central America', 'Culture', 'History', 'Human Rights', 'Literature', 'North America', 'South America', 'Writing\n']], ['AAAD-A 150 Survey of the Culture of Black Americans\n', ['Art', 'Crafts', 'Culture', 'History', 'Literature', 'North America', 'Performance', 'Religion\n']], ['AAAD-A 169 Introduction to African American Literature\n', ['Literature', 'North America\n']], ['AAAD-A 238 Communication in Black America\n', ['Communication', 'Culture', 'History', 'Language', 'Media', 'North America\n']], ['AAAD-A 249 African American Autobiography\n', ['Culture', 'History', 'Human Rights', 'Literature', 'North America', 'Religion', 'Writing\n']], ['AAAD-A 277 Images of Blacks in Films: 1903-1950s\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 278 Contemporary Black Film\n', ['Culture', 'History', 'Movies', 'North America\n']], ['AAAD-A 290 Sociocultural Perspective of African American Music\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAAD-A 295 Survey of Hip Hop\n', ['Culture', 'History', 'Media', 'Music', 'North America', 'Pop Culture\n']], ['AAAD-A 297 Popular Music of Black America\n', ['Culture', 'History', 'Music', 'North America\n']], ['AAST-A 200 Asian American Literature\n', ['Culture', 'History', 'Literature', 'North America\n']], ['AAST-A 201 Asian Diaspora Experience\n', ['Art', 'Asia', 'Culture', 'History', 'Literature', 'Media', 'Movies', 'Music', 'News', 'North America', 'Performance', 'Photography\n']], ['AMST-A 200 Comparative American Identities\n', ['Culture', 'Gender and LGBTQ+', 'Government', 'History', 'Human Rights', 'North America\n']], ['AMST-A 202 U.S. Arts and Media\n', ['Art', 'Media', 'North America\n']], ['ANTH-A 208 Topics in the Anthropology of the Arts and Expressive Behavior\n', ['Art', 'Crafts', 'Culture', 'History', 'Literature', 'Music', 'Performance', 'Religion\n']], ['ANTH-A 288 Sex, Drugs, and Rock-n-Roll (Subversive Culture)\n', ['Culture', 'Gender and LGBTQ+', 'Music', 'Pop Culture\n']], ['ANTH-E 203 Stigma and the Expressive Arts: Cultivating Compassion\n', ['Art', 'Culture', 'Gender and LGBTQ+', 'Helping People', 'Human Rights', 'Movies', 'Music', 'Performance', 'Photography', 'Writing\n']], ['ANTH-E 208 Global Jazz, Reggae, and Hip-Hop: African Diasporic Music Beyond the African Diaspora\n', ['Africa', 'Central America', 'Culture', 'Gender and LGBTQ+', 'History', 'Music', 'North America', 'Religion', 'South America\n']], ['ANTH-E 220 Performing Human/Nature: Defining Relationships with the Environment\n', ['Art', 'Culture', 'Journalism', 'Literature', 'Movies', 'Music\n']], ['ANTH-E 270 Captivity Narratives\n', ['Culture', 'History', 'Human Rights', 'International', 'Language', 'Literature\n']], ['ARTH-A 155 Introduction to African Art\n', ['Africa', 'Art', 'History\n']], ['ARTH-A 160 Introduction to East Asian Art\n', ['Art', 'Asia', 'Culture', 'History\n']], ['ARTH-A 200 Topics in Art History (Topic: Art of the Great Depression)\n', ['Art', 'History', 'Movies', 'Photography\n']], ['ARTH-A 203 Machine Age Modern: European Art, 1848-1939\n', ['Art', 'Culture', 'Europe', 'History', 'Media', 'Movies', 'Photography', 'Pop Culture\n']], ['ARTH-A 204 Buddha and Beyond: Keywords for the Study of East Asian Buddhist Art\n', ['Art', 'Asia', 'Language', 'Religion\n']], ['ARTH-A 205 Baroque Art in Europe: From Caravaggio to Rembrandt\n', ['Art', 'Europe', 'History\n']], ['ARTH-A 206 Classical Art and Archaeology\n', ['Art', 'Culture', 'Europe', 'History\n']], ['ARTH-A 207 Introduction to Contemporary Art and Its Discontents, 1960 to the Present\n', ['Art', 'Culture', 'History', 'Pop Culture\n']], ['ARTH-A 220 American Arts/American Identities\n', ['Art', 'Culture', 'History', 'North America', 'Photography', 'Pop Culture\n']], ['ARTH-A 224 The Gothic Cathedral\n', ['Art', 'Design', 'Europe', 'Government', 'History', 'Music', 'Religion\n']], ['ARTH-A 226 Envisioning the Sac ...

# %%
#Given Interests, and what category of class I need. Then I return the class code.

# %%
def recommended_class(interests, required):
    #Give it a list of interests, and of a string of required class, for example 'AH'
    #Then it chucks out a list [2, AAAD-A 132 Recent African American and African Diaspora Literature, ['Africa', 'Central America']]
    #The 2 represents number of interests matched, index 1 is class description, index 2 is  what matched.
    best_class = [1, 'classname']
    for i in hashmap[required]:
        count = 0
        reasons = []
        i[1][-1] = i[1][-1].strip()
        st = set(i[1])
        
        for j in interests:
            #print(j)
            if j in st:
                reasons.append(j)
                count += 1

        if count > best_class[0]:
            best_class = [count, i[0].strip(), reasons]

    
    return best_class



print(recommended_class(["Africa", "Central America"], 'AH'))
# Out:
# [2, 'AAAD-A 132 Recent African American and African Diaspora Literature', ['Africa', 'Central America']]
