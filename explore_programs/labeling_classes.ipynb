# %%
import pandas as pd
import numpy as np
import re
import csv

# %%
hashmap = {}

with open(r"explore_programs_geneds_raw.txt") as file:
   # if count % 3 == 1:
    content = file.readlines()

    tag_set = set()

    for i in range(len(content)):
        if i % 3 == 2:

            if len(content[i].strip()) > 2:
           
                val = content[i].strip()

                #print(val)

                first = val[:2]
                second = val[2:]

                lst = [first, second]
             #   print("hi i got here")
             ##   print(first, second)
                for z in lst:
                  #  print(z, type(z))
                    if z not in hashmap:
                        hashmap[z.strip()] = [content[i-2][:], re.split(r'#', content[i-1])[1:]]
                    else:
                        hashmap[z.strip()].append([content[i-2][:], re.split(r'#', content[i-1])[1:]])

           #     print("I worked", hashmap)

            elif content[i].strip() not in hashmap:

                hashmap[content[i].strip()] = [[content[i-2][:], set(re.split(r'#', content[i-1])[1:])]]
             #   print(hashmap)
            else:

                hashmap[content[i].strip()].append([content[i-2][:], set(re.split(r'#', content[i-1])[1:])])
 
        if i % 3 == 1:
            tag_set.update(re.split(r'#', content[i])[1:])
           # print(re.split(r'#', content[i])[1:])

 #   print(tag_set)
print(hashmap)
# Out:
# {'AH': [['AAAD-A 132 Recent African American and African Diaspora Literature\n', {'Literature', 'Central America', 'North America', 'Writing\n', 'Culture', 'South America', 'Africa', 'Human Rights', 'History'}], ['AAAD-A 150 Survey of the Culture of Black Americans\n', {'Literature', 'Religion\n', 'North America', 'Culture', 'Art', 'Performance', 'Crafts', 'History'}], ['AAAD-A 169 Introduction to African American Literature\n', {'Literature', 'North America\n'}], ['AAAD-A 238 Communication in Black America\n', {'Communication', 'Language', 'Culture', 'North America\n', 'Media', 'History'}], ['AAAD-A 249 African American Autobiography\n', {'Literature', 'North America', 'Writing\n', 'Culture', 'Human Rights', 'Religion', 'History'}], ['AAAD-A 277 Images of Blacks in Films: 1903-1950s\n', {'North America\n', 'Movies', 'Culture', 'History'}], ['AAAD-A 278 Contemporary Black Film\n', {'North America\n', 'Movies', 'Culture', 'History'}], ['AAAD-A 290 Sociocultural Perspective of African American Music\n', {'North America\n', 'Music', 'Culture', 'History'}], ['AAAD-A 295 Survey of Hip Hop\n', {'Music', 'Pop Culture\n', 'North America', 'Culture', 'Media', 'History'}], ['AAAD-A 297 Popular Music of Black America\n', {'North America\n', 'Music', 'Culture', 'History'}], ['AAST-A 200 Asian American Literature\n', {'Literature', 'North America\n', 'Culture', 'History'}], ['AAST-A 201 Asian Diaspora Experience\n', ['Art', 'Asia', 'Culture', 'History', 'Literature', 'Media', 'Movies', 'Music', 'News', 'North America', 'Performance', 'Photography\n']], ['AMST-A 200 Comparative American Identities\n', {'Culture', 'Government', 'North America\n', 'Human Rights', 'Gender and LGBTQ+', 'History'}], ['AMST-A 202 U.S. Arts and Media\n', {'Art', 'North America\n', 'Media'}], ['ANTH-A 208 Topics in the Anthropology of the Arts and Expressive Behavior\n', {'Literature', 'Music', 'Religion\n', 'Culture', 'Art', 'Performance', 'Crafts', 'History'}], ['ANTH-A 288 Sex, Drugs, and Rock-n-Roll (Subversive Culture)\n', {'Music', 'Pop Culture\n', 'Culture', 'Gender and LGBTQ+'}], ['ANTH-E 203 Stigma and the Expressive Arts: Cultivating Compassion\n', {'Music', 'Helping People', 'Movies', 'Culture', 'Writing\n', 'Art', 'Human Rights', 'Gender and LGBTQ+', 'Performance', 'Photography'}], ['ANTH-E 208 Global Jazz, Reggae, and Hip-Hop: African Diasporic Music Beyond the African Diaspora\n', {'Music', 'Central America', 'North America', 'Culture', 'Africa', 'Religion', 'Gender and LGBTQ+', 'South America\n', 'History'}], ['ANTH-E 220 Performing Human/Nature: Defining Relationships with the Environment\n', {'Literature', 'Music\n', 'Journalism', 'Movies', 'Culture', 'Art'}], ['ANTH-E 270 Captivity Narratives\n', {'Literature\n', 'Language', 'International', 'Culture', 'Human Rights', 'History'}], ['ARTH-A 155 Introduction to African Art\n', ['Africa', 'Art', 'History\n']], ['ARTH-A 160 Introduction to East Asian Art\n', {'Art', 'History\n', 'Culture', 'Asia'}], ['ARTH-A 200 Topics in Art History (Topic: Art of the Great Depression)\n', {'Art', 'Movies', 'Photography\n', 'History'}], ['ARTH-A 203 Machine Age Modern: European Art, 1848-1939\n', {'Pop Culture\n', 'Photography', 'Movies', 'Culture', 'Art', 'Europe', 'Media', 'History'}], ['ARTH-A 204 Buddha and Beyond: Keywords for the Study of East Asian Buddhist Art\n', ['Art', 'Asia', 'Language', 'Religion\n']], ['ARTH-A 205 Baroque Art in Europe: From Caravaggio to Rembrandt\n', ['Art', 'Europe', 'History\n']], ['ARTH-A 206 Classical Art and Archaeology\n', ['Art', 'Culture', 'Europe', 'History\n']], ['ARTH-A 207 Introduction to Contemporary Art and Its Discontents, 1960 to the Present\n', {'Art', 'Pop Culture\n', 'Culture', 'History'}], ['ARTH-A 220 American Arts/American Identities\n', {'Pop Culture\n', 'North America', 'Culture', 'History', 'Art', 'Photography'}], ['ARTH-A 224 The Gothic Cathedral\n', ['Art', 'Design', 'Europe', 'Government', 'History', 'Music', 'Religion\n']], ['ARTH-A 226 Envisioning the Sac ...

# %%
#Given Interests, and what category of class I need. Then I return the class code.

# %%
def recommended_class(interests, required):
    #Give it a list of interests, and of a string of required class, for example 'AH'
    #Then it chucks out a list [2, AAAD-A 132 Recent African American and African Diaspora Literature, ['Africa', 'Central America']]
    #The 2 represents number of interests matched, index 1 is class description, index 2 is  what matched.
    best_class = [1, 'classname']
    for i in hashmap[required]:
        count = 0
        reasons = []
        i[1][-1] = i[1][-1].strip()
        st = set(i[1])
        
        for j in interests:
            #print(j)
            if j in st:
                reasons.append(j)
                count += 1

        if count > best_class[0]:
            best_class = [count, i[0].strip(), reasons]

    
    return best_class



print(recommended_class(["Africa", "Central America"], 'AH'))
# Out:
# [2, 'AAAD-A 132 Recent African American and African Diaspora Literature', ['Africa', 'Central America']]
